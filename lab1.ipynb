# %%
# %%writefile processCreation.sh
# #!/bin/bash
#  echo "Parent Process ID:$$"
#  (
#   echo"Child 1 Process ID:$$, Parent process ID: $PPID"
#   sleep 5
#  )&
#
#  (
#   echo"Child 2 Process ID:$$, Parent process ID: $PPID"
#   sleep 5
#  )&
#  sleep 1
#  echo -e
#  ps -o pid,ppid,cmd --forest | grep -E "bash|sleep" | grep -v "grep"
# Out:
# Writing processCreation.sh

# %%
# !chmod +x processCreation.sh

# %%
# !bash processCreation.sh
# Out:
# Parent Process ID:2832
# processCreation.sh: line 4: echoChild 1 Process ID:2832, Parent process ID: 2538: command not found
# processCreation.sh: line 9: echoChild 2 Process ID:2832, Parent process ID: 2538: command not found
#
#      20       6  \_ /bin/bash -e /usr/local/colab/bin/oom_monitor.sh
#    2843      20  |   \_ sleep 1
#    2832    2538  |       \_ bash processCreation.sh
#    2833    2832  |           \_ bash processCreation.sh
#    2838    2833  |           |   \_ sleep 5
#    2834    2832  |           \_ bash processCreation.sh
#    2839    2834  |           |   \_ sleep 5
#      22       1 /bin/bash -e /datalab/run.sh
